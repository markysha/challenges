# %%
import pandas as pd

# %%
import os

# %%
df_master = pd.DataFrame(columns=[
    "test",
    "algo version",
    "time",
    "cut size",
])

df_master = pd.DataFrame(columns=[
    "test",
    "algo version",
    "time",
    "cut size",
])

with os.scandir('./') as entries:
    for entry in entries:
        if entry.name.split("_")[0] != "parhip":
            continue
        
        algo = entry.name.split("_")[1]
        test_num = entry.name.split("_")[2]
        k = entry.name.split("_")[6]
        configuration = entry.name.split("_")[-1]
        
        data = ""
        with open(entry.name) as f:
            data = f.read()
        
        lines = data.split("\n")
        
        n = lines[2].split(" ")[3]
        m = lines[2].split(" ")[5]
        time = lines[-4].split(" ")[-1]
        cut = lines[-3].split(" ")[-1]
        
        print(algo, test_num, k, configuration, n, m, time, cut, data)
# Out:
# updated 2 16 fastmesh 1010321 6454320 30.0274 919906 running collective dummy operations took 0.000860214
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 177265 amount 177266
# peID 5 from 803359 to peID 1010320 amount 206962
# peID 2 from 335104 to 4868203 from 486821 to 638808 amount 151988
#  amount 151717
# peID 4 from 638809 to 803358 amount 164550peID
# 1 from 177266 to 335103 amount 157838
# took 0.191198
# n:1010321 m: 6454320
# log> ghost edges 0.576891
# log> local edges 0.423109
# upper bound on blocks 65040
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 30.0274
# log>final edge cut 919906
# log>final balance 1.02998
#
# master 19 64 fastmesh 522482 3427578 30.617 684876 running collective dummy operations took 0.000829935
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 87080 amount 87081
# peID 1peID 2 from 174162 to 261242 amount peID 3 from 261243 to 348323 amount 87081peID 4 from 348324 to 435404 amount 87081
# peID 5 from 435405 to 522481 amount 87077
#  from 87081 to 174161 amount 87081
# 87081
#
# took 0.135752
# n:522482 m: 3427578
# log> ghost edges 0.577117
# log> local edges 0.422883
# upper bound on blocks 8408
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 30.617
# log>final edge cut 684876
# log>final balance 1.02989
#
# updated 11 64 fastmesh 952507 6138516 49.7404 1026954 running collective dummy operations took 0.000804901
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 160932 amount 160933
# peID 2 from 312788 to 461175 amount 148388
# peID 5 from 770126 to 952506 amount 182381
# peID 1 from 160933 to 312787 amount 151855
# peID 3 from 461176 to 615031 amount 153856
# peID 4 from 615032 to 770125 amount 155094
# took 0.177745
# n:952507 m: 6138516
# log> ghost edges 0.552287
# log> local edges 0.447713
# upper bound on blocks 15329
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 49.7404
# log>final edge cut 1026954
# log>final balance 1.02997
#
# master 19 16 fastmesh 522482 3427578 15.4334 518216 running collective dummy operations took 0.000785828
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 87080 amount 87081
# peID 1 from 87081 to 174161 amount 87081peID 2 from 174162 to 261242 amount 87081
# peID 3 from 261243 to 348323 amount 87081
# peID 4 from 348324 to 435404 amount 87081
# peID 5 from 435405 to 522481 amount 87077
#
# took 0.123769
# n:522482 m: 3427578
# log> ghost edges 0.577117
# log> local edges 0.422883
# upper bound on blocks 33635
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 15.4334
# log>final edge cut 518216
# log>final balance 1.02995
#
# updated 19 4 fastmesh 522482 3427578 10.0123 269936 running collective dummy operations took 0.000832081
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 84306 amount 84307
# peID 5 from 419606peID 2 from  to 522481 amount 102876
# 167451 to 258262 amount 90812
# peID 3 from 258263 to 342567 amount 84305
# peID 1 from peID 4 from 84307 to 167450 amount 83144
# 342568 to 419605 amount 77038
# took 0.09566
# n:522482 m: 3427578
# log> ghost edges 0.576875
# log> local edges 0.423125
# upper bound on blocks 134539
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 10.0123
# log>final edge cut 269936
# log>final balance 1.02999
#
# updated 14 64 ecomesh 630802 4097796 463.153 699535 running collective dummy operations took 0.000777006
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 107678 amount 107679
# peID 5 from 485757 to peID 2 from peID 3 from 295529630801 amount 145045
# peID 1203505 to 295528 amount 92024
#  to 387938 amount 92410
#  from 107679 to 203504 amount 95826
# peID 4 from 387939 to 485756 amount 97818
# took 0.104321
# n:630802 m: 4097796
# log> ghost edges 0.562172
# log> local edges 0.437828
# upper bound on blocks 10152
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 463.153
# log>final edge cut 699535
# log>final balance 1.02993
#
# master 19 64 ecomesh 522482 3427578 451.909 637044 running collective dummy operations took 0.000832081
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 87080 amount 87081
# peID peID 2 from peID 4 from 348324 to 435404 amount peID 5 from 435405 to 522481 amount 87077
# 1 from 87081 to 174161 amount 87081
# 174162 to 261242 amount 87081
# peID 3 from 261243 to 348323 amount 87081
# 87081
# took 0.121827
# n:522482 m: 3427578
# log> ghost edges 0.577117
# log> local edges 0.422883
# upper bound on blocks 8408
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 451.909
# log>final edge cut 637044
# log>final balance 1.02989
#
# master 2 4 ecomesh 1010321 6454320 405.164 470172 running collective dummy operations took 0.00162101
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 168386 amount 168387
# peID 1 from 168387 to 336773 amount 168387
# peID 2 from 336774 to 505160 amount 168387
# peID 3 from 505161 to 673547 amount 168387
# peID 4 from 673548 to 841934 amount 168387
# peID 5 from 841935 to 1010320 amount 168386
# took 0.243376
# n:1010321 m: 6454320
# log> ghost edges 0.56175
# log> local edges 0.43825
# upper bound on blocks 260158
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 405.164
# log>final edge cut 470172
# log>final balance 1.02999
#
# updated 6 4 ecomesh 1011662 6775020 390.986 426566 running collective dummy operations took 0.000844002
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 164718 amount 164719
# peID 5 from 810698 to 1011661 amount 200964
# peID 2 from peID 3 from 483535 to 314870 to 483534 amount 168665
# 633378 amount 149844
# peID 1 from peID 4 from 633379 to 164719 to 314869 amount 150151
# 810697 amount 177319
# took 0.20823
# n:1011662 m: 6775020
# log> ghost edges 0.451475
# log> local edges 0.548525
# upper bound on blocks 260503
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 390.986
# log>final edge cut 426566
# log>final balance 1.02999
#
# updated 9 16 fastmesh 844332 5796786 22.7491 814603 running collective dummy operations took 0.000932932
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 145199 amount 145200
# peID 1 from 145200 to 285822 amount 140623
# peID 2 from 285823 to 424823 amount 139001
# peID 3 from 424824 to 575140 amount 150317
# peID 4 from 575141 to 704496 amount 129356
# peID 5 from 704497 to 844331 amount 139835
# took 0.19466
# n:844332 m: 5796786
# log> ghost edges 0.670311
# log> local edges 0.329689
# upper bound on blocks 54354
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 22.7491
# log>final edge cut 814603
# log>final balance 1.02998
#
# updated 12 4 fastmesh 1293436 9547128 41.0956 889849 running collective dummy operations took 0.00659108
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 2 from 393735 to 614607 amount 220873
# peID 3 from 614608 to 830413 amount 215806
# peID 4 from 830414 to 1053004 amount 222591
# peID 5 from 1053005 to 1293435 amount 240431
# peID 0 from 0 to 196199 amount 196200
# peID 1 from 196200 to 393734 amount 197535
# took 0.475379
# n:1293436 m: 9547128
# log> ghost edges 0.68982
# log> local edges 0.31018
# upper bound on blocks 333059
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 41.0956
# log>final edge cut 889849
# log>final balance 1.03
#
# master 11 64 ecomesh 952507 6138516 513.902 932499 running collective dummy operations took 0.00071907
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 158751 amount 158752
# peID 1 from 158752 to 317503 amount 158752peID 2 from 317504 to 476255 amount 158752
# peID 3 from 476256 to 635007 amount 158752
# peID 4 from 635008 to 793759 amount 158752
# peID 5 from 793760 to 952506 amount 158747
#
# took 0.220807
# n:952507 m: 6138516
# log> ghost edges 0.551093
# log> local edges 0.448907
# upper bound on blocks 15329
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 513.902
# log>final edge cut 932499
# log>final balance 1.02997
#
# updated 12 4 ecomesh 1293436 9547128 417.463 837061 running collective dummy operations took 0.00100303
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 3peID 5 from 1053005 to 1293435 amount 240431peID 0 from 0 to 196199 amount 196200
# peID 1 from 196200 to 393734 amount 197535
#  from 614608 to 830413 amount 215806
#
# peID 2 from 393735 to 614607 amount peID 4 from 220873
# 830414 to 1053004 amount 222591
# took 0.334302
# n:1293436 m: 9547128
# log> ghost edges 0.68982
# log> local edges 0.31018
# upper bound on blocks 333059
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 417.463
# log>final edge cut 837061
# log>final balance 1.02999
#
# master 9 16 fastmesh 844332 5796786 26.4615 818721 running collective dummy operations took 0.00114393
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 140721 amount 140722
# peID peID 3 from 4221661 from 140722 to 281443 amount 140722
#  to 562887 amount 140722
# peID 4 from 562888 to 703609 amount 140722
# peID peID 5 from 703610 to 844331 amount 140722
# 2 from 281444 to 422165 amount 140722
# took 0.240788
# n:844332 m: 5796786
# log> ghost edges 0.680821
# log> local edges 0.319179
# upper bound on blocks 54354
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 26.4615
# log>final edge cut 818721
# log>final balance 1.02998
#
# updated 16 64 fastmesh 698339 4560826 24.7437 610160 running collective dummy operations took 0.000815868
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 115331 amount 115332
# peID 5 from 557280 to peID 4698338 amount 141059
# peID 1 from 115332 to 227846 amount 112515 from 447448 to 557279 amount 109832
#
# peID 2 from 227847 to 340095 amount 112249
# peID 3 from 340096 to 447447 amount 107352
# took 0.14281
# n:698339 m: 4560826
# log> ghost edges 0.547119
# log> local edges 0.452881
# upper bound on blocks 11239
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 24.7437
# log>final edge cut 610160
# log>final balance 1.02988
#
# updated 6 64 ecomesh 1011662 6775020 453.272 1078651 running collective dummy operations took 0.00072217
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 164718peID 5 from 810698 to 1011661 amount 200964
#  amount 164719
# peID 3 from peID 1 from 483535 to 633378 amount 149844
# 164719 to 314869 amount 150151
# peID 2 from 314870peID 4 from 633379 to 810697 amount 177319 to 483534 amount 168665
#
# took 0.174564
# n:1011662 m: 6775020
# log> ghost edges 0.451475
# log> local edges 0.548525
# upper bound on blocks 16282
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 453.272
# log>final edge cut 1078651
# log>final balance 1.02998
#
# master 7 16 fastmesh 1360217 9862830 48.6592 1174720 running collective dummy operations took 0.00257492
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 226702 amount 226703
# peID peID 51 from 226703 to 453405 amount peID 2 from 453406 to 680108 amount 226703
# peID 3 from 680109 to 906811 amount 226703
# peID 4 from 906812 to 1133514 amount 226703
#  from 1133515 to 1360216 amount 226702226703
#
# took 0.370377
# n:1360217 m: 9862830
# log> ghost edges 0.679892
# log> local edges 0.320108
# upper bound on blocks 87564
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 48.6592
# log>final edge cut 1174720
# log>final balance 1.02998
#
# updated 14 64 fastmesh 630802 4097796 31.8522 759148 running collective dummy operations took 0.000893116
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 107678 amount 107679
# peID 5 from 485757 to 630801 amount 145045
# peID 3 from 295529peID 2 to 387938 amount 92410
# peID 4 from 387939 to 485756 amount 97818
# peID 1 from 107679 to  from 203505 to 295528 amount 92024
# 203504 amount 95826
# took 0.111832
# n:630802 m: 4097796
# log> ghost edges 0.562172
# log> local edges 0.437828
# upper bound on blocks 10152
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 31.8522
# log>final edge cut 759148
# log>final balance 1.02983
#
# updated 6 64 fastmesh 1011662 6775020peID 45.226 1173034 running collective dummy operations took 0.000933886
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020peID 5 from 810698 to 1011661 amount 200964
#
# peID 1 from 164719 to peID 3 from 483535 to 633378 amount 149844
# peID 314869 amount 150151
# peID 2 from 314870 to 483534 amount 168665
# peID 4 from 633379 to 810697 amount 177319
# 0 from 0 to 164718 amount 164719
# took 0.1896
# n:1011662 m: 6775020
# log> ghost edges 0.451475
# log> local edges 0.548525
# upper bound on blocks 16282
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 45.226
# log>final edge cut 1173034
# log>final balance 1.02992
#
# updated 12 64 ecomesh 1293436 9547128 639.602 1815161 running collective dummy operations took 0.00109887
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 2 from 393735 to 614607 amount 220873
# peID 3 from 614608 to 830413 amount 215806
# peID 4 from 830414 to peID 5 from 1053005 to 1293435 amount 240431
# 1053004 amount 222591
# peID 0 from 0 to 196199 amount 196200
# peID 1 from 196200 to 393734 amount 197535
# took 0.476028
# n:1293436 m: 9547128
# log> ghost edges 0.68982
# log> local edges 0.31018
# upper bound on blocks 20816
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 639.602
# log>final edge cut 1815161
# log>final balance 1.02999
#
# master 7 4 fastmesh 1360217 9862830 45.7129 626527 running collective dummy operations took 0.000875235
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 226702 amount 226703
# peID peID 4 from peID 5 from 1133515 to 1360216 amount 226702peID 1 from 226703 to 453405 amount 226703
# peID 2 from 453406 to 680108 amount 226703
# 3 from 680109 to 906811 amount 226703
# 906812 to 1133514 amount 226703
#
# took 0.39732
# n:1360217 m: 9862830
# log> ghost edges 0.679892
# log> local edges 0.320108
# upper bound on blocks 350256
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 45.7129
# log>final edge cut 626527
# log>final balance 1.03
#
# updated 2 64 fastmesh 1010321 6454320 62.4995 1154793 running collective dummy operations took 0.000960112
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 3 from peID 2 from 335104 to 486820 amount 151717
# 486821 to 638808 amount 151988
# peID 0 from 0 to 177265 amount 177266
# peID 1 from 177266 to 335103 amount 157838
# peID 4 from peID 5 from 803359 to 1010320 amount 206962
# 638809 to 803358 amount 164550
# took 0.24048
# n:1010321 m: 6454320
# log> ghost edges 0.576891
# log> local edges 0.423109
# upper bound on blocks 16260
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 62.4995
# log>final edge cut 1154793
# log>final balance 1.0299
#
# updated 14 16 fastmesh 630802 4097796 16.3009 577270 running collective dummy operations took 0.000818014
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 107678 amount 107679
# peID peID 1 from 107679peID 2 from 203505 to 295528 amount 92024
# peID 3 from 295529 to 387938 amount 92410
# peID 4 from 387939 to 485756 amount 97818
# 5 from 485757 to 630801 amount 145045
#  to 203504 amount 95826
# took 0.114882
# n:630802 m: 4097796
# log> ghost edges 0.562172
# log> local edges 0.437828
# upper bound on blocks 40608
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 16.3009
# log>final edge cut 577270
# log>final balance 1.02995
#
# master 12 16 ecomesh 1293436 9547128 475.867 1531972 running collective dummy operations took 0.000761986
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID peID 2 from 431146 to 646718peID 3 from 646719 to 862291 amount 215573
# peID 4 from 862292 to 1077864 amount 215573
# peID 5 from 1077865 to 1293435 amount 215571
# 1 from 215573 to 431145 amount 215573
#  amount 215573
# took 0.428292
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 83265
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 475.867
# log>final edge cut 1531972
# log>final balance 1.02999
#
# master 6 4 fastmesh 1011662 6775020 23.385 460703 running collective dummy operations took 0.000905037
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 168610 amount 168611
# peID 1 from 168611 to 337221 amount 168611
# peID 2 from 337222 to 505832 amount 168611
# peID 3 from 505833 to 674443 amount 168611
# peID 4 from 674444 to 843054 amount 168611
# peID 5 from 843055 to 1011661 amount 168607
# took 0.222886
# n:1011662 m: 6775020
# log> ghost edges 0.47762
# log> local edges 0.52238
# upper bound on blocks 260503
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 23.385
# log>final edge cut 460703
# log>final balance 1.02999
#
# master 3 4 ecomesh 917944 6218868 386.664 394799 running collective dummy operations took 0.000870943
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 152990 amount 152991
# peID 1peID 5 from 764955 to 917943 from 152991 to 305981 amount 152991
# peID 2 from 305982 to 458972 amount 152991
# peID 3 from 458973 to 611963 amount 152991
# peID 4 from 611964 to 764954 amount 152991
#  amount 152989
# took 0.207783
# n:917944 m: 6218868
# log> ghost edges 0.432129
# log> local edges 0.567871
# upper bound on blocks 236370
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 386.664
# log>final edge cut 394799
# log>final balance 1.02999
#
# updated 12 64 fastmesh 1293436 9547128 98.2863 1945108 running collective dummy operations took 0.00112009
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 5 from 1053005 to 1293435 amount 240431
# peID 3 from 614608 to 830413 amount 215806
# peID 4 from 830414 to peID 0 from 0 to 196199 amount 196200
# 1053004 amount 222591
# peID 1 from 196200 to 393734 amount 197535
# peID 2 from 393735 to 614607 amount 220873
# took 0.513166
# n:1293436 m: 9547128
# log> ghost edges 0.68982
# log> local edges 0.31018
# upper bound on blocks 20816
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 98.2863
# log>final edge cut 1945108
# log>final balance 1.02999
#
# updated 3 4 ecomesh 917944 6218868 380.865 401573 running collective dummy operations took 0.000830173
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 155113 amount 155114
# peID 5peID  from 715373 to 917943 amount 202571
# 2 from 295680 to 423875 amount 128196
# peID 3 from 423876 to 568702 amount 144827
# peID 1 from 155114 to 295679 amount 140566
# peID 4 from 568703 to 715372 amount 146670
# took 0.147458
# n:917944 m: 6218868
# log> ghost edges 0.461881
# log> local edges 0.538119
# upper bound on blocks 236370
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 380.865
# log>final edge cut 401573
# log>final balance 1.03
#
# master 9 4 ecomesh 844332 5796786 383.542 385152 running collective dummy operations took 0.000831842
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 140721 amount 140722
# peID peID 4 from 562888 to 703609 amount 140722peID 1 from 140722 to 281443 amount 140722
# peID 2 from 281444 to 422165 amount 140722
# 3 from 422166 to 562887 amount 140722
#
# peID 5 from 703610 to 844331 amount 140722
# took 0.245858
# n:844332 m: 5796786
# log> ghost edges 0.680821
# log> local edges 0.319179
# upper bound on blocks 217415
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 383.542
# log>final edge cut 385152
# log>final balance 1.03
#
# updated 19 64 fastmesh 522482 3427578 26.3628 688018 running collective dummy operations took 0.000838995
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 84306 amount 84307
# peID 5peID 2 from 167451 to  from 419606 to 522481 amount 102876
# peID 1 from 258262 amount 90812
# 84307 to 167450 amount 83144
# peID 3 from peID 4 from 342568 to 419605 amount 258263 to 342567 amount 84305
# 77038
# took 0.0950758
# n:522482 m: 3427578
# log> ghost edges 0.576875
# log> local edges 0.423125
# upper bound on blocks 8408
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 26.3628
# log>final edge cut 688018
# log>final balance 1.02989
#
# master 2 16 fastmesh 1010321 6454320 33.0978 992433 running collective dummy operations took 0.000921011
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 168386 amount 168387
# peID 1peID 3 from 505161 to 673547 from 168387 to 336773 amount 168387
# peID 2 from 336774 to 505160 amount 168387
#  amount 168387
# peID 4 from 673548 to 841934 amount 168387
# peID 5 from 841935 to 1010320 amount 168386
# took 0.248575
# n:1010321 m: 6454320
# log> ghost edges 0.56175
# log> local edges 0.43825
# upper bound on blocks 65040
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 33.0978
# log>final edge cut 992433
# log>final balance 1.02998
#
# master 16 4 ecomesh 698339 4560826 377.442 280529 running collective dummy operations took 0.000827789
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 116389 amount 116390
# peID 3peID 4 from 465560 to peID 5 from 581950 to 698338 amount 116389
# peID 1 from 116390 to 232779 amount 116390
# peID 2 from 232780 to 349169 amount 116390
#  from 349170 to 465559 amount 116390
# 581949 amount 116390
# took 0.174345
# n:698339 m: 4560826
# log> ghost edges 0.519757
# log> local edges 0.480243
# upper bound on blocks 179822
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 377.442
# log>final edge cut 280529
# log>final balance 1.02993
#
# master 7 64 ecomesh 1360217 9862830 561.537 1472042 running collective dummy operations took 0.000748158
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 226702 amount 226703
# peID 1peID 5 from 1133515 from 226703 to 453405 amount 226703
# peID 2 from 453406 to 680108 amount 226703
# peID 3 from 680109 to 906811 amount 226703
# peID 4 from 906812 to 1133514 amount 226703
#  to 1360216 amount 226702
# took 0.381013
# n:1360217 m: 9862830
# log> ghost edges 0.679892
# log> local edges 0.320108
# upper bound on blocks 21891
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 561.537
# log>final edge cut 1472042
# log>final balance 1.02992
#
# updated 7 64 fastmesh 1360217 9862830 71.3327 1646016 running collective dummy operations took 0.002563
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 221728 amount 221729
# peID 2 from 434270 to 640590 amount 206321peID 1 from 221729 to 434269 amount 212541
# peID 3 from 640591 to 860294
#  amount 219704
# peID 4 from peID 5 from 1073535 to 1360216 amount 286682
# 860295 to 1073534 amount 213240
# took 0.438836
# n:1360217 m: 9862830
# log> ghost edges 0.690021
# log> local edges 0.309979
# upper bound on blocks 21891
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 71.3327
# log>final edge cut 1646016
# log>final balance 1.02992
#
# updated 12 16 fastmesh 1293436 9547128 48.0612 1713226 running collective dummy operations took 0.000983
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 196199 amount 196200
# peID 1 from 196200 to 393734 amount 197535
# peID 2 from 393735 to 614607 amount 220873
# peID 3 from peID 4 from 830414 to 1053004 amount 222591peID 5 from 1053005 to 1293435 amount 240431
# 614608 to 830413 amount 215806
#
# took 0.392161
# n:1293436 m: 9547128
# log> ghost edges 0.68982
# log> local edges 0.31018
# upper bound on blocks 83265
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 48.0612
# log>final edge cut 1713226
# log>final balance 1.02999
#
# master 11 64 fastmesh 952507 6138516 53.0814 979196 running collective dummy operations took 0.000807047
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 158751 amount 158752
# peID 1 from peID 2 from 317504 to peID 3 from 476256 to 635007 amount 158752
# peID 4 from 635008 to 793759 amount 158752
# peID 5 from 793760 to 952506 amount 158747
# 158752 to 317503 amount 158752
# 476255 amount 158752
# took 0.228235
# n:952507 m: 6138516
# log> ghost edges 0.551093
# log> local edges 0.448907
# upper bound on blocks 15329
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 53.0814
# log>final edge cut 979196
# log>final balance 1.02997
#
# master 3 64 ecomesh 917944 6218868 479.428 980136 running collective dummy operations took 0.000718832
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 152990 amount 152991
# peID 1peID 2 from 305982 to 458972peID 3 from 458973 to 611963 amount 152991peID 4 from 611964 to 764954 amount 152991
# peID 5 from 764955 to 917943 amount 152989
#  from 152991 to 305981 amount 152991
#  amount 152991
#
# took 0.176647
# n:917944 m: 6218868
# log> ghost edges 0.432129
# log> local edges 0.567871
# upper bound on blocks 14773
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 479.428
# log>final edge cut 980136
# log>final balance 1.02998
#
# updated 3 64 fastmesh 917944 6218868 40.09 1060624 running collective dummy operations took 0.000802994
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 155113 amount 155114
# peID 5 from 715373peID 2 from 295680 to  to 917943 amount 202571
# 423875 amount 128196
# peID 3 from 423876 to 568702 amount 144827
# peID 1 from 155114 to 295679 amount 140566
# peID 4 from 568703 to 715372 amount 146670
# took 0.145187
# n:917944 m: 6218868
# log> ghost edges 0.461881
# log> local edges 0.538119
# upper bound on blocks 14773
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 40.09
# log>final edge cut 1060624
# log>final balance 1.02998
#
# master 14 16 fastmesh 630802 4097796 18.0384 575270 running collective dummy operations took 0.000905037
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 105133 amount 105134
# peID 1 from 105134 to 210267 amount 105134
# peID 3 from 315402 to 420535 amount 105134
# peID 4 from 420536 to 525669 amount 105134
# peID 5 from 525670 to 630801 amount 105132
# peID 2 from 210268 to 315401 amount 105134
# took 0.14026
# n:630802 m: 4097796
# log> ghost edges 0.501373
# log> local edges 0.498627
# upper bound on blocks 40608
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 18.0384
# log>final edge cut 575270
# log>final balance 1.02995
#
# updated 9 16 ecomesh 844332 5796786 401.764 768911 running collective dummy operations took 0.000827789
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 145199 amount 145200
# peID 5 from 704497 to 844331 amount 139835
# peID 2 from peID 3 from 424824 to 575140 amount peID 1 from 145200 to 285823 to 424823 amount 139001
# 150317
# 285822 amount 140623
# peID 4 from 575141 to 704496 amount 129356
# took 0.189539
# n:844332 m: 5796786
# log> ghost edges 0.670311
# log> local edges 0.329689
# upper bound on blocks 54354
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 401.764
# log>final edge cut 768911
# log>final balance 1.02998
#
# updated 11 64 ecomesh 952507 6138516 489.144 948885 running collective dummy operations took 0.000832796
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID peID 2 from 312788peID 3 from 461176 to 615031 amount 153856
# 5 from 770126 to 952506 amount 182381
# peID 0 from 0 to 160932 amount 160933
# peID 1 from 160933 to 312787 amount 151855
#  to 461175 amount 148388
# peID 4 from 615032 to 770125 amount 155094
# took 0.172512
# n:952507 m: 6138516
# log> ghost edges 0.552287
# log> local edges 0.447713
# upper bound on blocks 15329
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 489.144
# log>final edge cut 948885
# log>final balance 1.02997
#
# master 14 16 ecomesh 630802 4097796 394.41 544554 running collective dummy operations took 0.000720024
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 105133 amount 105134
# peID 2peID 3 from 315402 to 420535peID 4 from 420536 to 525669 amount 105134peID 5 from 525670 to 630801 amount 105132
# peID 1 from 105134 to 210267 amount 105134
#  from 210268 to 315401 amount 105134
#  amount 105134
#
# took 0.137621
# n:630802 m: 4097796
# log> ghost edges 0.501373
# log> local edges 0.498627
# upper bound on blocks 40608
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 394.41
# log>final edge cut 544554
# log>final balance 1.02995
#
# master 2 4 fastmesh 1010321 6454320 28.7656 491441 running collective dummy operations took 0.00090313
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 168386 amount 168387
# peID 5 from peID 1 from peID 2 from 336774 to 505160 amount 168387
# peID 3 from 505161 to 673547 amount 168387
# peID 4 from 673548 to 841934 amount 168387
# 841935 to 1010320 amount 168386
# 168387 to 336773 amount 168387
# took 0.233403
# n:1010321 m: 6454320
# log> ghost edges 0.56175
# log> local edges 0.43825
# upper bound on blocks 260158
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 28.7656
# log>final edge cut 491441
# log>final balance 1.02998
#
# master 12 64 fastmesh 1293436 9547128 97.8655 1971839 running collective dummy operations took 0.000792027
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID 1 from peID 2 from 431146 to 646718 amount peID 3 from 646719 to 862291 amount 215573
# peID 4 from 862292 to 1077864 amount 215573
# peID 5 from 1077865 to 1293435 amount 215571
# 215573 to 431145 amount 215573
# 215573
# took 0.396165
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 20816
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 97.8655
# log>final edge cut 1971839
# log>final balance 1.02999
#
# updated 2 16 ecomesh 1010321 6454320 418.005 810084 running collective dummy operations took 0.00105596
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 3 from 486821 to 638808 amount 151988
# peID 2 from 335104peID 0 from  to 486820 amount 151717
# 0 to 177265 amount 177266
# peID 1 from 177266 to 335103 amount 157838
# peID 4 from 638809 to peID 5 from 803359 to 1010320 amount 206962
# 803358 amount 164550
# took 0.242856
# n:1010321 m: 6454320
# log> ghost edges 0.576891
# log> local edges 0.423109
# upper bound on blocks 65040
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 418.005
# log>final edge cut 810084
# log>final balance 1.02998
#
# master 2 64 ecomesh 1010321 6454320 550.148 1096888 running collective dummy operations took 0.000787973
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 168386 amount 168387
# peID peID 3 from 505161peID 4 from 673548 to 841934 amount 168387
# peID 5 from 841935 to 1010320 amount 168386
# peID 1 from 168387 to 336773 amount 168387
# 2 from 336774 to 505160 amount 168387
#  to 673547 amount 168387
# took 0.241609
# n:1010321 m: 6454320
# log> ghost edges 0.56175
# log> local edges 0.43825
# upper bound on blocks 16260
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 550.148
# log>final edge cut 1096888
# log>final balance 1.02996
#
# master 12 4 ecomesh 1293436 9547128 431.227 822504 running collective dummy operations took 0.00210094
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID 2peID 4 from 862292 to peID 5 from 1077865 to 1293435 amount 215571peID 1 from 215573 to 431145 amount 215573
#  from 431146 to 646718 amount 215573
# peID 3 from 646719 to 862291 amount 215573
# 1077864 amount 215573
#
# took 0.400903
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 333059
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 431.227
# log>final edge cut 822504
# log>final balance 1.02999
#
# master 12 16 fastmesh 1293436 9547128 56.6169 1642316 running collective dummy operations took 0.00094986
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID peID 2peID 3 from 646719 to peID 4 from 862292 to 1077864 amount 215573
# peID 5 from 1077865 to 1293435 amount 215571
# 1 from 215573 to 431145 amount 215573
#  from 431146 to 646718 amount 215573
# 862291 amount 215573
# took 0.42948
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 83265
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 56.6169
# log>final edge cut 1642316
# log>final balance 1.02999
#
# updated 7 4 fastmesh 1360217 9862830 31.7122 594464 running collective dummy operations took 0.000957012
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 2 from 434270 to 640590 amount 206321
# peID 3 from 640591 to 860294 amount 219704
# peID 0 from 0 to 221728 amount 221729
# peID 1 from 221729 to 434269 amount 212541
# peID 4 from 860295 to 1073534 amount 213240
# peID 5 from 1073535 to 1360216 amount 286682
# took 0.418028
# n:1360217 m: 9862830
# log> ghost edges 0.690021
# log> local edges 0.309979
# upper bound on blocks 350256
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 31.7122
# log>final edge cut 594464
# log>final balance 1.02995
#
# master 16 4 fastmesh 2 232780 15.1485 316470 running collective dummy operations took 0.000873089
# Reading binary graph ...
# version: 3peID peID 2 from 232780 to 349169 amount 116390
# peID 3 from 349170 to 465559peID 5 from 581950 to 698338 amount 116389
# 1 from 116390 to 232779 amount 116390
#  amount 116390
# peID 4 from 465560 to 581949 amount 116390
#  n: 698339 m: 4560826
# peID 0 from 0 to 116389 amount 116390
# took 0.150356
# n:698339 m: 4560826
# log> ghost edges 0.519757
# log> local edges 0.480243
# upper bound on blocks 179822
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 15.1485
# log>final edge cut 316470
# log>final balance 1.03
#
# master 12 64 ecomesh 1293436 9547128 635.597 1804044 running collective dummy operations took 0.00079298
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID 4 from peID 1 from 215573 to 431145 amount 215573peID 2 from 431146 to 646718 amount 215573
# peID 3 from 646719 to 862291 amount 215573
# 862292 to 1077864 amount 215573
# peID 5 from 1077865 to 1293435 amount 215571
#
# took 0.388935
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 20816
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 635.597
# log>final edge cut 1804044
# log>final balance 1.02999
#
# master 9 64 fastmesh 844332 5796786 42.625 1109844 running collective dummy operations took 0.000799894
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 140721 amount 140722
# peID 1 from peID 3 from 422166 to 562887 amount 140722peID 4 from 562888 to 703609 amount peID 5 from 703610 to 844331 amount 140722
# 140722 to 281443 amount 140722
# peID 2 from 281444 to 422165 amount 140722
#
# 140722
# took 0.242069
# n:844332 m: 5796786
# log> ghost edges 0.680821
# log> local edges 0.319179
# upper bound on blocks 13588
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 42.625
# log>final edge cut 1109844
# log>final balance 1.02994
#
# master 16 16 fastmesh 698339 4560826 17.7995 463101 running collective dummy operations took 0.000833988
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 116389 amount 116390
# peID 2 from 232780peID 3 from 349170 to 465559 amount 116390
# peID 4 from 465560 to 581949 amount 116390
# peID 1 from 116390 to 232779 amount 116390
#  to 349169 amount 116390
# peID 5 from 581950 to 698338 amount 116389
# took 0.152431
# n:698339 m: 4560826
# log> ghost edges 0.519757
# log> local edges 0.480243
# upper bound on blocks 44956
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 17.7995
# log>final edge cut 463101
# log>final balance 1.02997
#
# updated 14 16 ecomesh 630802 4097796 391.895 548227 running collective dummy operations took 0.000771999
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 107678 amount 107679
# peID 5peID 2 from 203505 to peID 3 from 295529 to 387938 amount 92410
#  from 485757 to 630801 amount 145045
# 295528 amount 92024
# peID 1 from 107679 to 203504 amount 95826
# peID 4 from 387939 to 485756 amount 97818
# took 0.10362
# n:630802 m: 4097796
# log> ghost edges 0.562172
# log> local edges 0.437828
# upper bound on blocks 40608
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 391.895
# log>final edge cut 548227
# log>final balance 1.02995
#
# updated 7 16 ecomesh 1360217 9862830 447.397 1118514 running collective dummy operations took 0.0014689
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 221728 amount 221729
# peID 1 from 221729 to 434269 amount 212541
# peID 2 from 434270 to 640590 amount 206321
# peID 3 from 640591 to 860294 amount 219704
# peID 5 from 1073535 to 1360216 amount 286682
# peID 4 from 860295 to 1073534 amount 213240
# took 0.511562
# n:1360217 m: 9862830
# log> ghost edges 0.690021
# log> local edges 0.309979
# upper bound on blocks 87564
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 447.397
# log>final edge cut 1118514
# log>final balance 1.02998
#
# master 14 64 ecomesh 630802 4097796 461.023 719494 running collective dummy operations took 0.000840902
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 105133 amount 105134
# peID peID 2 from 210268 to 315401peID 3 from 315402 to 420535 amount 105134
# peID 4 from 420536 to 525669 amount 105134peID 5 from 525670 to 630801 amount 105132
# 1 from 105134 to 210267 amount 105134
#  amount 105134
#
# took 0.139328
# n:630802 m: 4097796
# log> ghost edges 0.501373
# log> local edges 0.498627
# upper bound on blocks 10152
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 461.023
# log>final edge cut 719494
# log>final balance 1.02983
#
# updated 11 16 ecomesh 952507 6138516 405.268 700981 running collective dummy operations took 0.000993013
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 4 from peID 5 from 770126 to 952506 amount 182381615032 to 770125 amount 155094
#
# peID 0 from 0 to 160932 amount 160933
# peID 1 from 160933 to 312787 amount 151855
# peID 2 from 312788 to 461175 amount 148388
# peID 3 from 461176 to 615031 amount 153856
# took 0.210644
# n:952507 m: 6138516
# log> ghost edges 0.552287
# log> local edges 0.447713
# upper bound on blocks 61317
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 405.268
# log>final edge cut 700981
# log>final balance 1.02998
#
# updated 3 4 fastmesh 917944 6218868 17.6526 385415 running collective dummy operations took 0.000873089
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 155113 amount 155114
# peID 1 from 155114 to 295679 amount 140566
# peID 2 from 295680 to 423875 amount 128196
# peID 3 from 423876 to 568702 amount 144827
# peID 4 from 568703 to 715372 amount 146670
# peID 5 from 715373 to 917943 amount 202571
# took 0.151892
# n:917944 m: 6218868
# log> ghost edges 0.461881
# log> local edges 0.538119
# upper bound on blocks 236370
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 17.6526
# log>final edge cut 385415
# log>final balance 1.02991
#
# updated 9 64 ecomesh 844332 5796786 484.459 1028040 running collective dummy operations took 0.000751972
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 145199 amount 145200
# peID 5 from 704497 to 844331 amount 139835
# peID peID 3 from 424824 to 575140 amount 150317
# peID 2 from 285823 to 424823 amount 139001
# 1 from 145200 to 285822 amount 140623
# peID 4 from 575141 to 704496 amount 129356
# took 0.186607
# n:844332 m: 5796786
# log> ghost edges 0.670311
# log> local edges 0.329689
# upper bound on blocks 13588
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 484.459
# log>final edge cut 1028040
# log>final balance 1.02994
#
# updated 6 16 ecomesh 1011662 6775020 423.498 852530 running collective dummy operations took 0.00136709
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 164718 amount 164719
# peID 5 from 810698 to 1011661 amount 200964
# peID 3 from peID 483535 to 633378 amount 149844
# 1 from 164719 to 314869 amount 150151
# peID 2 from peID 4 from 633379 to 810697314870 to 483534 amount 168665
#  amount 177319
# took 0.201414
# n:1011662 m: 6775020
# log> ghost edges 0.451475
# log> local edges 0.548525
# upper bound on blocks 65125
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 423.498
# log>final edge cut 852530
# log>final balance 1.02999
#
# master 7 64 fastmesh 1360217 9862830 80.6506 1608064 running collective dummy operations took 0.00101805
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 226702 amount 226703
# peID 1 from 226703 to 453405 amount 226703
# peID 2 from 453406 to 680108 amount 226703
# peID 3 from 680109 to 906811 amount 226703
# peID 4 from 906812 to 1133514 amount 226703
# peID 5 from 1133515 to 1360216 amount 226702
# took 0.41818
# n:1360217 m: 9862830
# log> ghost edges 0.679892
# log> local edges 0.320108
# upper bound on blocks 21891
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 80.6506
# log>final edge cut 1608064
# log>final balance 1.02992
#
# updated 16 16 ecomesh 698339 4560826 380.812 441812 running collective dummy operations took 0.00080204
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 115331 amount 115332
# peID 5 from 557280 to 698338 amount 141059
# peID 3 from 340096peID 4 from 447448 to 557279 amount 109832 to 447447 amount 107352
#
# peID 1 from 115332 to 227846 amount 112515peID 2 from 227847 to 340095 amount 112249
#
# took 0.133607
# n:698339 m: 4560826
# log> ghost edges 0.547119
# log> local edges 0.452881
# upper bound on blocks 44956
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 380.812
# log>final edge cut 441812
# log>final balance 1.02997
#
# updated 9 4 ecomesh 844332 5796786 380.347 431744 running collective dummy operations took 0.000832081
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 145199 amount 145200
# peID 5 from 704497 to peID 3 from 844331 amount 139835
# 424824 to 575140 amount 150317
# peID 2peID 1 from 285823 to 424823 amount 139001
#  from 145200 to 285822 amount 140623
# peID 4 from 575141 to 704496 amount 129356
# took 0.194189
# n:844332 m: 5796786
# log> ghost edges 0.670311
# log> local edges 0.329689
# upper bound on blocks 217415
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 380.347
# log>final edge cut 431744
# log>final balance 1.03
#
# master 12 4 fastmesh 1293436 9547128 51.0468 892998 running collective dummy operations took 0.000802994
# Reading binary graph ...
# version: 3 n: 1293436 m: 9547128
# peID 0 from 0 to 215572 amount 215573
# peID peID 2 from 431146 to 646718 amount peID 3 from 646719 to 862291 amount 215573peID 4 from 862292 to 1077864 amount 215573
# 1 from 215573 to 431145 amount 215573
# 215573
#
# peID 5 from 1077865 to 1293435 amount 215571
# took 0.438451
# n:1293436 m: 9547128
# log> ghost edges 0.697138
# log> local edges 0.302862
# upper bound on blocks 333059
# log>=====================================
# ...
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 481.204
# log>final edge cut 1091417
# log>final balance 1.02998
#
# master 3 64 fastmesh 917944 6218868 44.3635 1047946 running collective dummy operations took 0.000870943
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 152990 amount 152991
# peID peID 1 from 152991 to 3059812 from 305982 to 458972 amount 152991peID 3 from 458973 to 611963 amount peID 4 from 611964 to 764954 amount 152991
# peID 5 from 764955 to 917943 amount 152989
#  amount 152991
#
# 152991
# took 0.18357
# n:917944 m: 6218868
# log> ghost edges 0.432129
# log> local edges 0.567871
# upper bound on blocks 14773
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 44.3635
# log>final edge cut 1047946
# log>final balance 1.02998
#
# updated 3 64 ecomesh 917944 6218868 457.426 984937 running collective dummy operations took 0.000780106
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 155113 amount 155114
# peID peID peID 3 from 5 from 715373 to 917943 amount 202571
# 2 from 295680 to 423875 amount 128196
# 423876 to 568702 amount 144827
# peID 1 from 155114 to 295679 amount 140566
# peID 4 from 568703 to 715372 amount 146670
# took 0.143714
# n:917944 m: 6218868
# log> ghost edges 0.461881
# log> local edges 0.538119
# upper bound on blocks 14773
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 457.426
# log>final edge cut 984937
# log>final balance 1.02998
#
# master 9 4 fastmesh 844332 5796786 20.8036 478736 running collective dummy operations took 0.000832796
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 140721 amount 140722
# peID 1peID 4 from 562888 to 703609 amount 140722 from 140722 to 281443 amount 140722
# peID 2 from 281444 to 422165 amount 140722
# peID 3 from 422166 to 562887 amount 140722
#
# peID 5 from 703610 to 844331 amount 140722
# took 0.232716
# n:844332 m: 5796786
# log> ghost edges 0.680821
# log> local edges 0.319179
# upper bound on blocks 217415
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 20.8036
# log>final edge cut 478736
# log>final balance 1.03
#
# updated 7 16 fastmesh 1360217 9862830 39.7289 1161243 running collective dummy operations took 0.00100613
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 221728 amount 221729
# peID 1 from 221729 to 434269 amount 212541
# peID 2 from 434270 to 640590 amount 206321
# peID 3 from 640591 to 860294 amount 219704
# peID 5 from peID 4 from 1073535 to 1360216 amount 286682
# 860295 to 1073534 amount 213240
# took 0.440566
# n:1360217 m: 9862830
# log> ghost edges 0.690021
# log> local edges 0.309979
# upper bound on blocks 87564
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 39.7289
# log>final edge cut 1161243
# log>final balance 1.02998
#
# updated 11 16 fastmesh 952507 6138516 24.7386 745215 running collective dummy operations took 0.00079608
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 160932 amount 160933
# peID peID 3 from 461176 to 615031 amount 153856
# 5 from 770126 to 952506 amount 182381
# peID 1 from 160933 to 312787 amount 151855
# peID 2 from 312788 to 461175 amount 148388peID 4 from 615032 to 770125 amount 155094
#
# took 0.175805
# n:952507 m: 6138516
# log> ghost edges 0.552287
# log> local edges 0.447713
# upper bound on blocks 61317
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 24.7386
# log>final edge cut 745215
# log>final balance 1.02998
#
# updated 16 4 fastmesh 698339 4560826 12.6203 307471 running collective dummy operations took 0.000798941
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 115331peID 5 from 557280 to 698338 amount 141059
#  amount 115332
# peID 3 from 340096 to 447447 amount 107352
# peID peID 4 from 447448 to 5572791 from 115332 to 227846 amount 112515
# peID 2 from 227847 to 340095 amount 112249
#  amount 109832
# took 0.138458
# n:698339 m: 4560826
# log> ghost edges 0.547119
# log> local edges 0.452881
# upper bound on blocks 179822
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 12.6203
# log>final edge cut 307471
# log>final balance 1.02999
#
# updated 11 4 fastmesh 952507 6138516 22.9031 388147 running collective dummy operations took 0.000878811
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 160932 amount 160933
# peID 1 from 160933 to 312787 amount 151855
# peID 2 from 312788 to 461175 amount 148388
# peID 3 from 461176 to 615031 amount 153856
# peID 4 from 615032 to 770125 amount 155094
# peID 5 from 770126 to 952506 amount 182381
# took 0.189903
# n:952507 m: 6138516
# log> ghost edges 0.552287
# log> local edges 0.447713
# upper bound on blocks 245270
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 22.9031
# log>final edge cut 388147
# log>final balance 1.02995
#
# master 6 16 ecomesh 1011662 6775020 424.542 826100 running collective dummy operations took 0.000895023
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 168610 amount 168611
# peID 1peID 3 from 505833 to 674443peID 4 from 674444 to 843054 amount 168611
#  from 168611 to 337221 amount 168611
# peID 2 from 337222 to 505832 amount 168611
#  amount 168611
# peID 5 from 843055 to 1011661 amount 168607
# took 0.24963
# n:1011662 m: 6775020
# log> ghost edges 0.47762
# log> local edges 0.52238
# upper bound on blocks 65125
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 424.542
# log>final edge cut 826100
# log>final balance 1.02999
#
# master 16 64 fastmesh 698339 4560826 27.7276 621875 running collective dummy operations took 0.000884056
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 116389 amount 116390
# peID 1 from 116390 to 232779 amount 116390
# peID 2 from 232780 to 349169 amount 116390
# peID 3 from 349170 to 465559 amount 116390
# peID 4 from 465560 to 581949 amount 116390
# peID 5 from 581950 to 698338 amount 116389
# took 0.193346
# n:698339 m: 4560826
# log> ghost edges 0.519757
# log> local edges 0.480243
# upper bound on blocks 11239
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 27.7276
# log>final edge cut 621875
# log>final balance 1.02988
#
# master 7 4 ecomesh 1360217 9862830 416.116 574374 running collective dummy operations took 0.000818968
# Reading binary graph ...
# version: 3 n: 1360217 m: 9862830
# peID 0 from 0 to 226702 amount 226703
# peID 2 from peID 1 from 226703 to 453405 amount 226703453406 to 680108 amount 226703
# peID 3 from 680109 to 906811 amount 226703
# peID 4 from 906812 to 1133514 amount 226703
# peID 5 from 1133515 to 1360216 amount 226702
#
# took 0.430872
# n:1360217 m: 9862830
# log> ghost edges 0.679892
# log> local edges 0.320108
# upper bound on blocks 350256
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 416.116
# log>final edge cut 574374
# log>final balance 1.03
#
# updated 2 4 ecomesh 1010321 6454320 391.379 450636 running collective dummy operations took 0.000838995
# Reading binary graph ...
# version: 3 n: 1010321 m: 6454320
# peID 0 from 0 to 177265 amount 177266
# peID 5peID 3 from 486821 to 638808 from 803359 to 1010320 amount 206962
# peID  amount 151988
# 1 from 177266 to 335103 amount 157838peID 2 from 335104 to 486820 amount 151717
#
# peID 4 from 638809 to 803358 amount 164550
# took 0.228046
# n:1010321 m: 6454320
# log> ghost edges 0.576891
# log> local edges 0.423109
# upper bound on blocks 260158
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 391.379
# log>final edge cut 450636
# log>final balance 1.02032
#
# master 9 64 ecomesh 844332 5796786 475.657 1030080 running collective dummy operations took 0.000757933
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 140721 amount 140722
# peID 2peID 4 from 562888 to 703609peID 5 from 703610 to 844331 amount 140722
# peID 1 from 140722 to 281443 amount 140722
#  from 281444 to 422165 amount 140722
# peID 3 from 422166 to 562887 amount 140722
#  amount 140722
# took 0.234274
# n:844332 m: 5796786
# log> ghost edges 0.680821
# log> local edges 0.319179
# upper bound on blocks 13588
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 475.657
# log>final edge cut 1030080
# log>final balance 1.02994
#
# updated 6 4 fastmesh 1011662 6775020 20.0413 461557 running collective dummy operations took 0.000862122
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 164718 amount 164719
# peID 5 from 810698 to 1011661 amount 200964
# peID 1 from 164719 to 314869 amount 150151
# peID 2 from 314870 to 483534 amount 168665
# peID 3 from 483535 to 633378 amount 149844
# peID 4 from 633379 to 810697 amount 177319
# took 0.178122
# n:1011662 m: 6775020
# log> ghost edges 0.451475
# log> local edges 0.548525
# upper bound on blocks 260503
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 20.0413
# log>final edge cut 461557
# log>final balance 1.02999
#
# master 6 4 ecomesh 1011662 6775020 401.903 444937 running collective dummy operations took 0.000988007
# Reading binary graph ...
# version: 3 n: 1011662 m: 6775020
# peID 0 from 0 to 168610 amount 168611
# peID 1 from 168611 to 337221 amount 168611peID 2 from 337222 to 505832 amount peID 3 from 505833 to 674443 amount 168611
# peID 5 from 843055 to 1011661 amount 168607
#
# 168611
# peID 4 from 674444 to 843054 amount 168611
# took 0.22083
# n:1011662 m: 6775020
# log> ghost edges 0.47762
# log> local edges 0.52238
# upper bound on blocks 260503
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 401.903
# log>final edge cut 444937
# log>final balance 1.02999
#
# updated 9 64 fastmesh 844332 5796786 36.6218 1129137 running collective dummy operations took 0.000884056
# Reading binary graph ...
# version: 3 n: 844332 m: 5796786
# peID 0 from 0 to 145199 amount 145200
# peID 5 from 704497 to 844331 amount 139835peID
# 1 from 145200 to 285822 amount 140623peID 4 from 575141
#  to 704496 amount 129356
# peID peID 3 from 4248242 from 285823 to 424823 amount 139001
#  to 575140 amount 150317
# took 0.199294
# n:844332 m: 5796786
# log> ghost edges 0.670311
# log> local edges 0.329689
# upper bound on blocks 13588
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 36.6218
# log>final edge cut 1129137
# log>final balance 1.02994
#
# updated 19 4 ecomesh 522482 3427578 363.035 252868 running collective dummy operations took 0.000857115
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 0 from 0 to 84306 amount 84307
# peID 5 from 419606 to 522481 amount 102876
# peID 2 from peID 3 from peID 1 from 167451 to 258262 amount 90812
# 258263 to 342567 amount 84305
# 84307 to 167450 amount 83144
# peID 4 from 342568 to 419605 amount 77038
# took 0.094702
# n:522482 m: 3427578
# log> ghost edges 0.576875
# log> local edges 0.423125
# upper bound on blocks 134539
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 363.035
# log>final edge cut 252868
# log>final balance 1.03
#
# updated 19 16 ecomesh 522482 3427578 378.091 458946 running collective dummy operations took 0.00104713
# Reading binary graph ...
# version: 3 n: 522482 m: 3427578
# peID 5 from 419606 to peID 2 from 167451 to 258262 amount 90812
# 522481 amount 102876
# peID 3 from 258263 to 342567 amount peID 4 from 342568 to 419605 amount 77038peID 1 from 84307 to 167450 amount 83144
# 84305
#
# peID 0 from 0 to 84306 amount 84307
# took 0.0931861
# n:522482 m: 3427578
# log> ghost edges 0.576875
# log> local edges 0.423125
# upper bound on blocks 33635
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 378.091
# log>final edge cut 458946
# log>final balance 1.02995
#
# master 16 16 ecomesh 698339 4560826 391.427 448033 running collective dummy operations took 0.000830889
# Reading binary graph ...
# version: 3 n: 698339 m: 4560826
# peID 0 from 0 to 116389 amount 116390
# peID peID 2 from 232780peID 3 from 349170 to 465559 amount peID 4 from 465560 to 581949 amount 116390
# peID 5 from 581950 to 698338 amount 116389
# 1 from 116390 to 232779 amount 116390
#  to 349169 amount 116390
# 116390
# took 0.148577
# n:698339 m: 4560826
# log> ghost edges 0.519757
# log> local edges 0.480243
# upper bound on blocks 44956
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 391.427
# log>final edge cut 448033
# log>final balance 1.02997
#
# master 11 4 fastmesh 952507 6138516 24.5955 445363 running collective dummy operations took 0.00097084
# Reading binary graph ...
# version: 3 n: 952507 m: 6138516
# peID 0 from 0 to 158751 amount 158752
# peID 1peID 2 from 317504 to 476255 amount peID 3 from 476256 to 635007 amount 158752peID 5 from 793760 to 952506 amount 158747
#  from 158752 to 317503 amount 158752
# 158752
#
# peID 4 from 635008 to 793759 amount 158752
# took 0.226248
# n:952507 m: 6138516
# log> ghost edges 0.551093
# log> local edges 0.448907
# upper bound on blocks 245270
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 24.5955
# log>final edge cut 445363
# log>final balance 1.03
#
# master 3 4 fastmesh 917944 6218868 19.7185 408109 running collective dummy operations took 0.000849962
# Reading binary graph ...
# version: 3 n: 917944 m: 6218868
# peID 0 from 0 to 152990 amount 152991
# peID 1 from peID 2 from 305982 to 458972 amount peID 3 from 458973 to 611963 amount 152991
# peID 4 from 611964 to 764954 amount 152991
# peID 5 from 764955 to 917943 amount 152989
# 152991 to 305981 amount 152991
# 152991
# took 0.180006
# n:917944 m: 6218868
# log> ghost edges 0.432129
# log> local edges 0.567871
# upper bound on blocks 236370
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 19.7185
# log>final edge cut 408109
# log>final balance 1.02998
#
# master 14 64 fastmesh 630802 4097796 33.2965 772086 running collective dummy operations took 0.00116706
# Reading binary graph ...
# version: 3 n: 630802 m: 4097796
# peID 0 from 0 to 105133 amount 105134
# peID 2 from 210268peID 3 from 315402 to 420535 amount 105134
# peID 4 from 420536 to 525669 amount 105134
# peID 1 from 105134 to 210267 amount 105134
#  to 315401 amount 105134
# peID 5 from 525670 to 630801 amount 105132
# took 0.147023
# n:630802 m: 4097796
# log> ghost edges 0.501373
# log> local edges 0.498627
# upper bound on blocks 10152
# log>=====================================
# log>============AND WE R DONE============
# log>=====================================
# log>total partitioning time elapsed 33.2965
# log>final edge cut 772086
# log>final balance 1.02983
